# %% [markdown]
# # <u> Statistical Treatment for Retail Data <u/>

# %% [markdown]
# ## 1. Perkenalan
# > Nama : M. Dwi Pratama

# %% [markdown]
# ## 2. Identifikasi Masalah
# ### 2.1 Latar Belakang
# > Terjadinya perang dunia pada tahun 1939-1945 mempengaruhi banyak sektor pada dunia ini, salah satunya yaitu sektor ekonomi. Untuk dapat menganalisis terkait dengan bangunan ataupun apartment yang memiliki nilai jual tinggi sehingga dapat dijadikan landasan dalam penjualan suatu bangunan properti, akan dilakukan suatu analisis statistika terkait data penjualan properti yang terjadi di New York City.
# ### 2.2 Data
# > Data yang digunakan adalah NYC property sales atau penjualan suatu properti (bangunan, apartmen, dll) di New York selama periode 12 bulan dimana data ini diambil dari website open source Kaggle. Data ini memuat sebanyak 24 kolom dan 28.439 baris data.
# ### 2.3 Problem Statement
# > Menganalisis secara statistika terkait dengan penjualan properti yang terjadi di New York City selama 12 bulan periode.
# ### 2.4 Success Criteria by SMART
# > **S** (Specific) : Mencari informasi penjualan properti yang terjadi di New York City selama data 12 bulan periode berdasarkan statistical treatment.
#
# > **M** (Measurable) : Dapat mengetahui rata-rata penjualan properti yang terjadi di New York City selama 12 bulan periode.
#
# > **A** (Achievable) : Berdasarkan Problem Statement akan diketahui beberapa informasi yang berkaitan dengan penjualan properti yang terjadi sepanjang 12 bulan periode berdasarkan data New York City sales.
#
# > **R** (Relevant) : Mengetahui tren penjualan properti yang terjadi di New York berdasarkan data New York City Sales.
#
# > **T** (Timely) : Lingkup tahun 2016 - 2017.

# %% [markdown]
# ## 3. Data Loading

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('nyc-rolling-sales.csv')

# %%
df
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 1        399   26                                  C7   234 EAST 4TH   STREET
# 2        399   39                                  C7   197 EAST 3RD   STREET
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#        ... RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0      ...                 5                 0            5              1633
# 1      ...                28                 3           31              4616
# 2      ...                16                 1           17              2212
# 3      ...                10                 0           10              2272
# 4      ...                 6                 0            6              2369
# ...    ...               ...               ...          ...               ...
# 84543  ...                 2                 0            2              2400
# 84544  ...                 2                 0            2              2498
# 84545  ...                 2                 0            2              4000
# 84546  ...                 0                 7            7            208033
# 84547  ...                 0                 1            1             10796
#
#        GROSS SQUARE FEET YEAR BUILT TAX CLASS AT TIME OF SALE  \
# 0                   6440       1900                         2
# 1                  18690       1900                         2
# 2                   7803       1900                         2
# 3                   6794       1913                         2
# 4                   4615       1900                         2
# ...                  ...        ...                       ...
# 84543               2575       1998                         1
# 84544               2377       1998                         1
# 84545               1496       1925                         1
# 84546              64117       2001                         4
# 84547               2400       2006                         4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE
# 0                                  C2     6625000  2017-07-19 00:00:00
# 1                                  C7         -    2016-12-14 00:00:00
# 2                                  C7         -    2016-12-09 00:00:00
# 3                                  C4     3936272  2016-09-23 00:00:00
# 4                                  C2     8000000  2016-11-17 00:00:00
# ...                               ...         ...                  ...
# 84543                              B9      450000  2016-11-28 00:00:00
# 84544                              B9      550000  2017-04-21 00:00:00
# 84545                              B2      460000  2017-07-05 00:00:00
# 84546                              K6    11693337  2016-12-21 00:00:00
# 84547                              P9       69300  2016-10-27 00:00:00
#
# [84548 rows x 22 columns]

# %% [markdown]
# Data yang digunakan merupakan catatan setiap bangunan atau unit bangunan (apartmen, dll) yang terjual di pasar properti New York City selama 1 tahun periode.
# Secara urutan Borough pada data menunjukkan 1-5 :Manhattan, Bronx, Brooklyn, Queens, dan Staten Island

# %% [markdown]
# ### 3.1 Data Filtering & Eksplorasi Data

# %%
df.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df.shape
# Out:
# (28439, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   EASE-MENT                       84548 non-null  object
#  7   BUILDING CLASS AT PRESENT       84548 non-null  object
#  8   ADDRESS                         84548 non-null  object
#  9   APARTMENT NUMBER                84548 non-null  object
#  10  ZIP CODE                        84548 non-null  int64
#  11  RESIDENTIAL UNITS               84548 non-null  int64
#  12  COMMERCIAL UNITS                84548 non-null  int64
#  13  TOTAL UNITS                     84548 non-null  int64
#  14  LAND SQUARE FEET                84548 non-null  object
#  15  GROSS SQUARE FEET               84548 non-null  object
#  16  YEAR BUILT                      84548 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  19  SALE PRICE                      84548 non-null  object
#  20  SALE DATE                       84548 non-null  object
# dtypes: int64(9), object(12)
# memory usage: 13.5+ MB

# %%
df.isna().sum()
# Out:
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %% [markdown]
# Terlihat dari hasil output diatas bahwa nilai null tidak terdeteksi pada dataframe tersebut, namun pada baris ke 2 kolom SALE PRICE terlihat bahwa terdapat missing values. Hal ini dikarenakan kolom SALE PRICE masih berbentuk datatype object (string). Maka kita harus mengubah kolom yang seharusnya memiliki datatype numeric (int/float) dengan function to_numeric

# %%
# Convert datatype to numeric
# Masukkan kolom-kolom yang ingin diubah kedalam list
numerik_variabel = ['SALE PRICE','LAND SQUARE FEET','GROSS SQUARE FEET','YEAR BUILT']

for i in numerik_variabel: 
    # coercing  kesalahan ke NA yang menempatkan kesalahan sebagai Nas
    df[i] = pd.to_numeric(df[i], errors='coerce')

# %%
df.isna().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26252
# GROSS SQUARE FEET                 27612
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14561
# SALE DATE                             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   EASE-MENT                       84548 non-null  object
#  7   BUILDING CLASS AT PRESENT       84548 non-null  object
#  8   ADDRESS                         84548 non-null  object
#  9   APARTMENT NUMBER                84548 non-null  object
#  10  ZIP CODE                        84548 non-null  int64
#  11  RESIDENTIAL UNITS               84548 non-null  int64
#  12  COMMERCIAL UNITS                84548 non-null  int64
#  13  TOTAL UNITS                     84548 non-null  int64
#  14  LAND SQUARE FEET                58296 non-null  float64
#  15  GROSS SQUARE FEET               56936 non-null  float64
#  16  YEAR BUILT                      84548 non-null  int64
#  17  TAX CLASS AT TIME OF SALE       84548 non-null  int64
#  18  BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  19  SALE PRICE                      69987 non-null  float64
#  20  SALE DATE                       84548 non-null  object
# dtypes: float64(3), int64(9), object(9)
# memory usage: 13.5+ MB

# %%
df.isna().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26252
# GROSS SQUARE FEET                 27612
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14561
# SALE DATE                             0
# dtype: int64

# %%
df
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                                  C2
# 1                        2    399   26                                  C7
# 2                        2    399   39                                  C7
# 3                       2B    402   21                                  C4
# 4                       2A    404   55                                  C2
# ...                    ...    ...  ...       ...                       ...
# 84543                    1   7349   34                                  B9
# 84544                    1   7349   78                                  B9
# 84545                    1   7351   60                                  B2
# 84546                    4   7100   28                                  K6
# 84547                    4   7105  679                                  P9
#
#                       ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0                153 AVENUE B                   ...                  5
# 1       234 EAST 4TH   STREET                   ...                 28
# 2       197 EAST 3RD   STREET                   ...                 16
# 3         154 EAST 7TH STREET                   ...                 10
# 4      301 EAST 10TH   STREET                   ...                  6
# ...                       ...              ...  ...                ...
# 84543           37 QUAIL LANE                   ...                  2
# 84544        32 PHEASANT LANE                   ...                  2
# 84545        49 PITNEY AVENUE                   ...                  2
# 84546   2730 ARTHUR KILL ROAD                   ...                  0
# 84547       155 CLAY PIT ROAD                   ...                  0
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                     0            5            1633.0             6440.0
# 1                     3           31            4616.0            18690.0
# 2                     1           17            2212.0             7803.0
# 3                     0           10            2272.0             6794.0
# 4                     0            6            2369.0             4615.0
# ...                 ...          ...               ...                ...
# 84543                 0            2            2400.0             2575.0
# 84544                 0            2            2498.0             2377.0
# 84545                 0            2            4000.0             1496.0
# 84546                 7            7          208033.0            64117.0
# 84547                 1            1           10796.0             2400.0
#
#        YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0            1900                          2                              C2
# 1            1900                          2                              C7
# 2            1900                          2                              C7
# 3            1913                          2                              C4
# 4            1900                          2                              C2
# ...           ...                        ...                             ...
# 84543        1998                          1                              B9
# 84544        1998                          1                              B9
# 84545        1925                          1                              B2
# 84546        2001                          4                              K6
# 84547        2006                          4                              P9
#
#        SALE PRICE            SALE DATE
# 0       6625000.0  2017-07-19 00:00:00
# 1             NaN  2016-12-14 00:00:00
# 2             NaN  2016-12-09 00:00:00
# 3       3936272.0  2016-09-23 00:00:00
# 4       8000000.0  2016-11-17 00:00:00
# ...           ...                  ...
# 84543    450000.0  2016-11-28 00:00:00
# 84544    550000.0  2017-04-21 00:00:00
# 84545    460000.0  2017-07-05 00:00:00
# 84546  11693337.0  2016-12-21 00:00:00
# 84547     69300.0  2016-10-27 00:00:00
#
# [84548 rows x 21 columns]

# %% [markdown]
# Kolom YEAR BUILT menunjukkan bahwa kapan bangunan tersebut didirikan, dan terlihat bahwa dari data tersebut terdapat data yang memiliki nilai YEAR BUILT yaitu 0, sehingga hal ini dapat dianggap sebagai missing values dan selanjutnya kita hapus nilai YEAR BUILT yang memiliki nilai 0

# %%
yearbuild = df[df['YEAR BUILT']==0]
yearbuild.count()
# Out:
# BOROUGH                           6970
# NEIGHBORHOOD                      6970
# BUILDING CLASS CATEGORY           6970
# TAX CLASS AT PRESENT              6970
# BLOCK                             6970
# LOT                               6970
# EASE-MENT                         6970
# BUILDING CLASS AT PRESENT         6970
# ADDRESS                           6970
# APARTMENT NUMBER                  6970
# ZIP CODE                          6970
# RESIDENTIAL UNITS                 6970
# COMMERCIAL UNITS                  6970
# TOTAL UNITS                       6970
# LAND SQUARE FEET                  3967
# GROSS SQUARE FEET                 2916
# YEAR BUILT                        6970
# TAX CLASS AT TIME OF SALE         6970
# BUILDING CLASS AT TIME OF SALE    6970
# SALE PRICE                        5391
# SALE DATE                         6970
# dtype: int64

# %%
# hapus baris dengan year_built = 0
df = df[df['YEAR BUILT']!=0]

# %% [markdown]
# Selanjutnya karna borough pada data mendefinisikan wilayahnya masing-masing seperti 1 : Manhattan, dan lainnya. Akan diubah code dari borough tersebut ke nama boroughnya agar mempermudah analisis

# %%
# Rename Borough
df['BOROUGH'][df['BOROUGH'] == 1] = 'Manhattan'

df['BOROUGH'][df['BOROUGH'] == 2] = 'Bronx'

df['BOROUGH'][df['BOROUGH'] == 3] = 'Brooklyn'

df['BOROUGH'][df['BOROUGH'] == 4] = 'Queens'

df['BOROUGH'][df['BOROUGH'] == 5] = 'Staten Island'
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 1] = 'Manhattan'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 1] = 'Manhattan'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 2] = 'Bronx'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 2] = 'Bronx'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 3] = 'Brooklyn'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 3] = 'Brooklyn'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 4] = 'Queens'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 4] = 'Queens'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 5] = 'Staten Island'
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1518809566.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BOROUGH'][df['BOROUGH'] == 5] = 'Staten Island'

# %%
df_group = df.groupby('BOROUGH')[['SALE PRICE']].sum()

# %%
df_group.sort_values(by='SALE PRICE', ascending=False)
# Out:
#                  SALE PRICE
# BOROUGH
# Manhattan      4.369265e+10
# Brooklyn       1.807655e+10
# Queens         1.289920e+10
# Bronx          4.000894e+09
# Staten Island  2.945297e+09

# %% [markdown]
# Dari hasil diatas terlihat bahwa borough yang memiliki total pendapatan paling tinggi terdapat pada wilayah Manhattan, dengan total pendapatan 50.246.190.000 dollar.

# %%
df
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 1          Manhattan  ALPHABET CITY
# 2          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 1        399   26                                  C7   234 EAST 4TH   STREET
# 2        399   39                                  C7   197 EAST 3RD   STREET
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0                       ...                  5                 0            5
# 1                       ...                 28                 3           31
# 2                       ...                 16                 1           17
# 3                       ...                 10                 0           10
# 4                       ...                  6                 0            6
# ...                ...  ...                ...               ...          ...
# 84543                   ...                  2                 0            2
# 84544                   ...                  2                 0            2
# 84545                   ...                  2                 0            2
# 84546                   ...                  0                 7            7
# 84547                   ...                  0                 1            1
#
#        LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                1633.0             6440.0        1900
# 1                4616.0            18690.0        1900
# 2                2212.0             7803.0        1900
# 3                2272.0             6794.0        1913
# 4                2369.0             4615.0        1900
# ...                 ...                ...         ...
# 84543            2400.0             2575.0        1998
# 84544            2498.0             2377.0        1998
# 84545            4000.0             1496.0        1925
# 84546          208033.0            64117.0        2001
# 84547           10796.0             2400.0        2006
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                              2                              C2   6625000.0
# 1                              2                              C7         NaN
# 2                              2                              C7         NaN
# 3                              2                              C4   3936272.0
# 4                              2                              C2   8000000.0
# ...                          ...                             ...         ...
# 84543                          1                              B9    450000.0
# 84544                          1                              B9    550000.0
# 84545                          1                              B2    460000.0
# 84546                          4                              K6  11693337.0
# 84547                          4                              P9     69300.0
#
#                  SALE DATE
# 0      2017-07-19 00:00:00
# 1      2016-12-14 00:00:00
# 2      2016-12-09 00:00:00
# 3      2016-09-23 00:00:00
# 4      2016-11-17 00:00:00
# ...                    ...
# 84543  2016-11-28 00:00:00
# 84544  2017-04-21 00:00:00
# 84545  2017-07-05 00:00:00
# 84546  2016-12-21 00:00:00
# 84547  2016-10-27 00:00:00
#
# [77578 rows x 21 columns]

# %% [markdown]
# Variabel pada kolom LAND SQUARE FEET mendefinisikan luas tanah yang tercantum dalam meter persegi, sehingga nilai 0 pada kolom LAND SQUARE FEET menimbulkan ambiguitas karena tidak mungkin suatu properti memiliki luas tanah 0 m^2. Nilai 0 pada kolom tersebut dapat dianggap sebagai outlier dan kita akan menghapus outlier tersebut.

# %%
df[df['LAND SQUARE FEET']==0]
# Out:
#         BOROUGH     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 18354     Bronx         BATHGATE  10 COOPS - ELEVATOR APARTMENTS
# 18355     Bronx         BATHGATE  10 COOPS - ELEVATOR APARTMENTS
# 18356     Bronx         BATHGATE  10 COOPS - ELEVATOR APARTMENTS
# 18746     Bronx       BAYCHESTER  04 TAX CLASS 1 CONDOS
# 18747     Bronx       BAYCHESTER  04 TAX CLASS 1 CONDOS
# ...         ...              ...                                          ...
# 49292  Brooklyn  WINDSOR TERRACE  44 CONDO PARKING
# 49293  Brooklyn  WINDSOR TERRACE  44 CONDO PARKING
# 49294  Brooklyn  WINDSOR TERRACE  47 CONDO NON-BUSINESS STORAGE
# 49295  Brooklyn  WINDSOR TERRACE  47 CONDO NON-BUSINESS STORAGE
# 49344  Brooklyn  WYCKOFF HEIGHTS  04 TAX CLASS 1 CONDOS
#
#       TAX CLASS AT PRESENT  BLOCK   LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 18354                    2   3035    48                                  D4
# 18355                    2   3035    48                                  D4
# 18356                    2   3044    40                                  D4
# 18746                   1A   4795  1009                                  R3
# 18747                   1A   4795  1027                                  R3
# ...                    ...    ...   ...       ...                       ...
# 49292                    4   5287  1035                                  RP
# 49293                    4   5287  1035                                  RP
# 49294                    4    895  1213                                  RS
# 49295                    4    895  1219                                  RS
# 49344                   1A   3200  1002                                  R3
#
#                          ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 18354  463 EAST 178TH STREET, 6E                   ...                  0
# 18355      463 EAST 178TH ST, 6B                   ...                  0
# 18356     495 E 178TH STREET, 2H                   ...                  0
# 18746            2877 ELY AVENUE                3  ...                  1
# 18747            2853 ELY AVENUE                3  ...                  1
# ...                          ...              ...  ...                ...
# 49292       207 PROSPECT PARK SW              P35  ...                  0
# 49293       207 PROSPECT PARK SW              P35  ...                  0
# 49294           11 TERRACE PLACE               S2  ...                  0
# 49295           11 TERRACE PLACE               S8  ...                  0
# 49344      54 ST NICHOLAS AVENUE               1B  ...                  1
#
#        COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 18354                 0            0               0.0                0.0
# 18355                 0            0               0.0                0.0
# 18356                 0            0               0.0                0.0
# 18746                 0            1               0.0                0.0
# 18747                 0            1               0.0                0.0
# ...                 ...          ...               ...                ...
# 49292                 0            1               0.0                0.0
# 49293                 0            1               0.0                0.0
# 49294                 0            1               0.0                0.0
# 49295                 0            1               0.0                0.0
# 49344                 0            1               0.0                0.0
#
#        YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 18354        1935                          2                              D4
# 18355        1935                          2                              D4
# 18356        1941                          2                              D4
# 18746        2008                          1                              R3
# 18747        2008                          1                              R3
# ...           ...                        ...                             ...
# 49292        1990                          4                              RP
# 49293        1990                          4                              RP
# 49294        2006                          4                              RS
# 49295        2006                          4                              RS
# 49344        1931                          1                              R3
#
#       SALE PRICE            SALE DATE
# 18354    40000.0  2017-04-17 00:00:00
# 18355    40000.0  2017-04-17 00:00:00
# 18356    60000.0  2016-12-01 00:00:00
# 18746   310000.0  2017-02-28 00:00:00
# 18747   342500.0  2017-07-31 00:00:00
# ...          ...                  ...
# 49292        0.0  2017-07-25 00:00:00
# 49293        0.0  2017-07-17 00:00:00
# 49294        0.0  2016-10-06 00:00:00
# 49295        0.0  2016-10-24 00:00:00
# 49344   510000.0  2017-07-13 00:00:00
#
# [8345 rows x 21 columns]

# %%
df = df[df['LAND SQUARE FEET']!=0]

# %% [markdown]
# Sama seperti dengan kolom LAND SQUARE FEET, GROSS SQUARE FEET mendefinisikan luas keseluruhan lantai yang diukur dari permukaan luar dinding. Sehingga tidak mungkin apabila GROSS SQUARE FEET memiliki nilai sebesar 0, selanjutnya kita akan menghapus nilai 0 pada kolom ini juga karna dapat terdeteksi sebagai outlier.

# %%
df[df['GROSS SQUARE FEET']==0]
# Out:
#         BOROUGH          NEIGHBORHOOD  \
# 18767     Bronx            BAYCHESTER
# 18909     Bronx  BEDFORD PARK/NORWOOD
# 18916     Bronx  BEDFORD PARK/NORWOOD
# 18917     Bronx  BEDFORD PARK/NORWOOD
# 19004     Bronx  BEDFORD PARK/NORWOOD
# ...         ...                   ...
# 48285  Brooklyn    WILLIAMSBURG-NORTH
# 48306  Brooklyn    WILLIAMSBURG-NORTH
# 48307  Brooklyn    WILLIAMSBURG-NORTH
# 48693  Brooklyn    WILLIAMSBURG-SOUTH
# 48694  Brooklyn    WILLIAMSBURG-SOUTH
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 18767  06 TAX CLASS 1 - OTHER                                         1
# 18909  05 TAX CLASS 1 VACANT LAND                                     2
# 18916  06 TAX CLASS 1 - OTHER                                         1
# 18917  06 TAX CLASS 1 - OTHER                                         1
# 19004  29 COMMERCIAL GARAGES                                          4
# ...                                            ...                  ...
# 48285  03 THREE FAMILY DWELLINGS                                      1
# 48306  07 RENTALS - WALKUP APARTMENTS                                2B
# 48307  07 RENTALS - WALKUP APARTMENTS                                2A
# 48693  01 ONE FAMILY DWELLINGS                                        1
# 48694  01 ONE FAMILY DWELLINGS                                        1
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 18767   4726   36                                  G0   3550 EASTCHESTER ROAD
# 18909   3287   94                                  D9      2681 MARION AVENUE
# 18916   3290   18                                  G0   N/A BAINBRIDGE AVENUE
# 18917   3290   18                                  G0   N/A BAINBRIDGE AVENUE
# 19004   3287   90                                  G7      2683 MARION AVENUE
# ...      ...  ...       ...                       ...                     ...
# 48285   2339    5                                  C0  278 NORTH 6TH   STREET
# 48306   2339    7                                  C1  282 NORTH 6TH   STREET
# 48307   2339    9                                  C2  288 NORTH 6TH   STREET
# 48693   2428   34                                  A5          5 WYTHE AVENUE
# 48694   2428   35                                  A5          6 WYTHE AVENUE
#
#       APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 18767                   ...                  0                 0            0
# 18909                   ...                100                 0          100
# 18916                   ...                  0                 0            0
# 18917                   ...                  0                 0            0
# 19004                   ...                  0                 0            0
# ...                ...  ...                ...               ...          ...
# 48285                   ...                  3                 0            3
# 48306                   ...                 10                 0           10
# 48307                   ...                  5                 0            5
# 48693                   ...                  1                 0            1
# 48694                   ...                  1                 0            1
#
#        LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 18767            3400.0                0.0        1955
# 18909           28786.0                0.0        2016
# 18916            2597.0                0.0        1950
# 18917            2597.0                0.0        1950
# 19004           14121.0                0.0        1915
# ...                 ...                ...         ...
# 48285            2500.0                0.0        2016
# 48306            2500.0                0.0        2016
# 48307            3407.0                0.0        2016
# 48693            1250.0                0.0        2015
# 48694            1250.0                0.0        2015
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 18767                          1                              G0   650000.0
# 18909                          1                              V0        0.0
# 18916                          1                              G0        0.0
# 18917                          1                              G0        0.0
# 19004                          4                              G7        0.0
# ...                          ...                             ...        ...
# 48285                          1                              C0        0.0
# 48306                          2                              C1        0.0
# 48307                          2                              C2        0.0
# 48693                          1                              A5  2269450.0
# 48694                          1                              A5  2269450.0
#
#                  SALE DATE
# 18767  2017-03-16 00:00:00
# 18909  2016-11-10 00:00:00
# 18916  2017-07-28 00:00:00
# 18917  2017-06-30 00:00:00
# 19004  2016-11-10 00:00:00
# ...                    ...
# 48285  2017-08-16 00:00:00
# 48306  2017-08-16 00:00:00
# 48307  2017-08-16 00:00:00
# 48693  2016-09-30 00:00:00
# 48694  2016-09-30 00:00:00
#
# [183 rows x 21 columns]

# %%
df = df[df['GROSS SQUARE FEET']!=0]

# %% [markdown]
# ## 4. Data Cleaning

# %%
df
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 1          Manhattan  ALPHABET CITY
# 2          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 1        399   26                                  C7   234 EAST 4TH   STREET
# 2        399   39                                  C7   197 EAST 3RD   STREET
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0                       ...                  5                 0            5
# 1                       ...                 28                 3           31
# 2                       ...                 16                 1           17
# 3                       ...                 10                 0           10
# 4                       ...                  6                 0            6
# ...                ...  ...                ...               ...          ...
# 84543                   ...                  2                 0            2
# 84544                   ...                  2                 0            2
# 84545                   ...                  2                 0            2
# 84546                   ...                  0                 7            7
# 84547                   ...                  0                 1            1
#
#        LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                1633.0             6440.0        1900
# 1                4616.0            18690.0        1900
# 2                2212.0             7803.0        1900
# 3                2272.0             6794.0        1913
# 4                2369.0             4615.0        1900
# ...                 ...                ...         ...
# 84543            2400.0             2575.0        1998
# 84544            2498.0             2377.0        1998
# 84545            4000.0             1496.0        1925
# 84546          208033.0            64117.0        2001
# 84547           10796.0             2400.0        2006
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                              2                              C2   6625000.0
# 1                              2                              C7         NaN
# 2                              2                              C7         NaN
# 3                              2                              C4   3936272.0
# 4                              2                              C2   8000000.0
# ...                          ...                             ...         ...
# 84543                          1                              B9    450000.0
# 84544                          1                              B9    550000.0
# 84545                          1                              B2    460000.0
# 84546                          4                              K6  11693337.0
# 84547                          4                              P9     69300.0
#
#                  SALE DATE
# 0      2017-07-19 00:00:00
# 1      2016-12-14 00:00:00
# 2      2016-12-09 00:00:00
# 3      2016-09-23 00:00:00
# 4      2016-11-17 00:00:00
# ...                    ...
# 84543  2016-11-28 00:00:00
# 84544  2017-04-21 00:00:00
# 84545  2017-07-05 00:00:00
# 84546  2016-12-21 00:00:00
# 84547  2016-10-27 00:00:00
#
# [69050 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  23249
# GROSS SQUARE FEET                 23558
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        12982
# SALE DATE                             0
# dtype: int64

# %% [markdown]
# Terlihat bahwa masih terdapat banyak missing values pada dataset tersebut, saya memutuskan untuk menghapus missing value yang ditemukan dari data tersebut.

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
df
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# 6          Manhattan  ALPHABET CITY
# 9          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# 6        406   32                                  C4            210 AVENUE B
# 9        387  153                                  D9     629 EAST 5TH STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0                       ...                  5                 0            5
# 3                       ...                 10                 0           10
# 4                       ...                  6                 0            6
# 6                       ...                  8                 0            8
# 9                       ...                 24                 0           24
# ...                ...  ...                ...               ...          ...
# 84543                   ...                  2                 0            2
# 84544                   ...                  2                 0            2
# 84545                   ...                  2                 0            2
# 84546                   ...                  0                 7            7
# 84547                   ...                  0                 1            1
#
#        LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                1633.0             6440.0        1900
# 3                2272.0             6794.0        1913
# 4                2369.0             4615.0        1900
# 6                1750.0             4226.0        1920
# 9                4489.0            18523.0        1920
# ...                 ...                ...         ...
# 84543            2400.0             2575.0        1998
# 84544            2498.0             2377.0        1998
# 84545            4000.0             1496.0        1925
# 84546          208033.0            64117.0        2001
# 84547           10796.0             2400.0        2006
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                              2                              C2   6625000.0
# 3                              2                              C4   3936272.0
# 4                              2                              C2   8000000.0
# 6                              2                              C4   3192840.0
# 9                              2                              D9  16232000.0
# ...                          ...                             ...         ...
# 84543                          1                              B9    450000.0
# 84544                          1                              B9    550000.0
# 84545                          1                              B2    460000.0
# 84546                          4                              K6  11693337.0
# 84547                          4                              P9     69300.0
#
#                  SALE DATE
# 0      2017-07-19 00:00:00
# 3      2016-09-23 00:00:00
# 4      2016-11-17 00:00:00
# 6      2016-09-23 00:00:00
# 9      2016-11-07 00:00:00
# ...                    ...
# 84543  2016-11-28 00:00:00
# 84544  2017-04-21 00:00:00
# 84545  2017-07-05 00:00:00
# 84546  2016-12-21 00:00:00
# 84547  2016-10-27 00:00:00
#
# [36805 rows x 21 columns]

# %%
# Kolom Age dibutuhkan untuk mengetahui usia dari properti atau bangunan tersebut.
df['AGE'] = 2023 - df['YEAR BUILT']

# Mengkelompokkan properti/bangunan berdasarkan usianya, sebelum atau sesudah terjadinya perang
df['AGE STATS'] = np.where(df['AGE']>=76, 'PRE-WAR', 'POST-WAR')

df
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1935229306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AGE'] = 2023 - df['YEAR BUILT']
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1935229306.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AGE STATS'] = np.where(df['AGE']>=76, 'PRE-WAR', 'POST-WAR')
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# 6          Manhattan  ALPHABET CITY
# 9          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# 6        406   32                                  C4            210 AVENUE B
# 9        387  153                                  D9     629 EAST 5TH STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                       ...            5            1633.0             6440.0
# 3                       ...           10            2272.0             6794.0
# 4                       ...            6            2369.0             4615.0
# 6                       ...            8            1750.0             4226.0
# 9                       ...           24            4489.0            18523.0
# ...                ...  ...          ...               ...                ...
# 84543                   ...            2            2400.0             2575.0
# 84544                   ...            2            2498.0             2377.0
# 84545                   ...            2            4000.0             1496.0
# 84546                   ...            7          208033.0            64117.0
# 84547                   ...            1           10796.0             2400.0
#
#        YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0            1900                          2                              C2
# 3            1913                          2                              C4
# 4            1900                          2                              C2
# 6            1920                          2                              C4
# 9            1920                          2                              D9
# ...           ...                        ...                             ...
# 84543        1998                          1                              B9
# 84544        1998                          1                              B9
# 84545        1925                          1                              B2
# 84546        2001                          4                              K6
# 84547        2006                          4                              P9
#
#        SALE PRICE            SALE DATE  AGE  AGE STATS
# 0       6625000.0  2017-07-19 00:00:00  123    PRE-WAR
# 3       3936272.0  2016-09-23 00:00:00  110    PRE-WAR
# 4       8000000.0  2016-11-17 00:00:00  123    PRE-WAR
# 6       3192840.0  2016-09-23 00:00:00  103    PRE-WAR
# 9      16232000.0  2016-11-07 00:00:00  103    PRE-WAR
# ...           ...                  ...  ...        ...
# 84543    450000.0  2016-11-28 00:00:00   25   POST-WAR
# 84544    550000.0  2017-04-21 00:00:00   25   POST-WAR
# 84545    460000.0  2017-07-05 00:00:00   98    PRE-WAR
# 84546  11693337.0  2016-12-21 00:00:00   22   POST-WAR
# 84547     69300.0  2016-10-27 00:00:00   17   POST-WAR
#
# [36805 rows x 23 columns]

# %% [markdown]
# Untuk mempermudah analisis kita akan mengubah nilai SALE PRICE menjadi dalam bentuk ribuan karna terlihat bahwa nilainya sangat besar kita akan membaginya dengan 1000.
# Note : SALE PRICE dalam bentuk dollar ($)

# %%
df['SALE PRICE(000)'] = df['SALE PRICE'].astype(np.float64) / 1000
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_18780\1576087263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SALE PRICE(000)'] = df['SALE PRICE'].astype(np.float64) / 1000

# %% [markdown]
# ## 5. Analisis Data

# %%
df
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# 6          Manhattan  ALPHABET CITY
# 9          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# 6        406   32                                  C4            210 AVENUE B
# 9        387  153                                  D9     629 EAST 5TH STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                       ...            1633.0             6440.0        1900
# 3                       ...            2272.0             6794.0        1913
# 4                       ...            2369.0             4615.0        1900
# 6                       ...            1750.0             4226.0        1920
# 9                       ...            4489.0            18523.0        1920
# ...                ...  ...               ...                ...         ...
# 84543                   ...            2400.0             2575.0        1998
# 84544                   ...            2498.0             2377.0        1998
# 84545                   ...            4000.0             1496.0        1925
# 84546                   ...          208033.0            64117.0        2001
# 84547                   ...           10796.0             2400.0        2006
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                              2                              C2   6625000.0
# 3                              2                              C4   3936272.0
# 4                              2                              C2   8000000.0
# 6                              2                              C4   3192840.0
# 9                              2                              D9  16232000.0
# ...                          ...                             ...         ...
# 84543                          1                              B9    450000.0
# 84544                          1                              B9    550000.0
# 84545                          1                              B2    460000.0
# 84546                          4                              K6  11693337.0
# 84547                          4                              P9     69300.0
#
#                  SALE DATE  AGE AGE STATS  SALE PRICE(000)
# 0      2017-07-19 00:00:00  123   PRE-WAR         6625.000
# 3      2016-09-23 00:00:00  110   PRE-WAR         3936.272
# 4      2016-11-17 00:00:00  123   PRE-WAR         8000.000
# 6      2016-09-23 00:00:00  103   PRE-WAR         3192.840
# 9      2016-11-07 00:00:00  103   PRE-WAR        16232.000
# ...                    ...  ...       ...              ...
# 84543  2016-11-28 00:00:00   25  POST-WAR          450.000
# 84544  2017-04-21 00:00:00   25  POST-WAR          550.000
# 84545  2017-07-05 00:00:00   98   PRE-WAR          460.000
# 84546  2016-12-21 00:00:00   22  POST-WAR        11693.337
# 84547  2016-10-27 00:00:00   17  POST-WAR           69.300
#
# [36805 rows x 24 columns]

# %%
df[df['SALE PRICE']<100]
# Out:
#              BOROUGH NEIGHBORHOOD  \
# 207        Manhattan      CHELSEA
# 208        Manhattan      CHELSEA
# 209        Manhattan      CHELSEA
# 832        Manhattan      CHELSEA
# 1072       Manhattan    CHINATOWN
# ...              ...          ...
# 84187  Staten Island  WILLOWBROOK
# 84194  Staten Island  WILLOWBROOK
# 84202  Staten Island  WILLOWBROOK
# 84301  Staten Island  WILLOWBROOK
# 84502  Staten Island      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 207    01 ONE FAMILY DWELLINGS                                        1
# 208    01 ONE FAMILY DWELLINGS                                        1
# 209    01 ONE FAMILY DWELLINGS                                        1
# 832    14 RENTALS - 4-10 UNIT                                        2A
# 1072   14 RENTALS - 4-10 UNIT                                        2B
# ...                                            ...                  ...
# 84187  01 ONE FAMILY DWELLINGS                                        1
# 84194  01 ONE FAMILY DWELLINGS                                        1
# 84202  01 ONE FAMILY DWELLINGS                                        1
# 84301  02 TWO FAMILY DWELLINGS                                        1
# 84502  02 TWO FAMILY DWELLINGS                                        1
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 207      772   29                                  A4  231 WEST 22ND   STREET
# 208      772   29                                  A4  231 WEST 22ND   STREET
# 209      772   29                                  A4  231 WEST 22ND   STREET
# 832      722   75                                  S3         256 10TH AVENUE
# 1072     199    1                                  S5        79 BAXTER STREET
# ...      ...  ...       ...                       ...                     ...
# 84187    734   13                                  A2          64 KELL AVENUE
# 84194    735  153                                  A1        32 CARMEL AVENUE
# 84202    744   14                                  A2       78 ARDMORE AVENUE
# 84301    749   14                                  B2       84 CRAFTON AVENUE
# 84502   6914   35                                  B2   1016 EDGEGROVE AVENUE
#
#       APARTMENT NUMBER  ...  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 207                     ...            1588.0             5653.0        1900
# 208                     ...            1588.0             5653.0        1900
# 209                     ...            1588.0             5653.0        1900
# 832                     ...            1146.0             3339.0        1910
# 1072                    ...            2500.0             9835.0        1890
# ...                ...  ...               ...                ...         ...
# 84187                   ...            6000.0              864.0        1950
# 84194                   ...            4000.0             1376.0        1925
# 84202                   ...            4000.0              960.0        1950
# 84301                   ...            4200.0             1870.0        1920
# 84502                   ...           10000.0             4526.0        1985
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 207                            1                              A4        10.0
# 208                            1                              A4        10.0
# 209                            1                              A4        10.0
# 832                            2                              S3        10.0
# 1072                           2                              S5        10.0
# ...                          ...                             ...         ...
# 84187                          1                              A2        10.0
# 84194                          1                              A1        10.0
# 84202                          1                              A2        10.0
# 84301                          1                              B2        10.0
# 84502                          1                              B2        10.0
#
#                  SALE DATE  AGE AGE STATS  SALE PRICE(000)
# 207    2017-01-30 00:00:00  123   PRE-WAR             0.01
# 208    2017-01-30 00:00:00  123   PRE-WAR             0.01
# 209    2017-01-30 00:00:00  123   PRE-WAR             0.01
# 832    2017-01-27 00:00:00  113   PRE-WAR             0.01
# 1072   2017-01-17 00:00:00  133   PRE-WAR             0.01
# ...                    ...  ...       ...              ...
# 84187  2017-02-24 00:00:00   73  POST-WAR             0.01
# 84194  2017-05-12 00:00:00   98   PRE-WAR             0.01
# 84202  2017-07-27 00:00:00   73  POST-WAR             0.01
# 84301  2017-02-24 00:00:00  103   PRE-WAR             0.01
# 84502  2017-02-03 00:00:00   38  POST-WAR             0.01
#
# [8156 rows x 24 columns]

# %% [markdown]
# Dari data tersebut banyak terdapat nilai SALE PRICE yang memiliki nilai 0 dari definisi data tersebut diketahui sebagai kasus pengalihan akta antar pihak : Misalnya, orang tua yang mengalihkan kepemilikan rumah kepada anaknya setelah pindah untuk pensiun. Oleh karena itu, saya akan memfilter data yang digunakan dengan properti yang terjual lebih dari 5000 dollar dan kurang dari 500 juta dollar

# %%
df = df[(df['SALE PRICE']>5000) & (df['SALE PRICE']<500000000)]

# %%
df
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 0          Manhattan  ALPHABET CITY
# 3          Manhattan  ALPHABET CITY
# 4          Manhattan  ALPHABET CITY
# 6          Manhattan  ALPHABET CITY
# 9          Manhattan  ALPHABET CITY
# ...              ...            ...
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84545  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# 6      07 RENTALS - WALKUP APARTMENTS                                2B
# 9      08 RENTALS - ELEVATOR APARTMENTS                               2
# ...                                            ...                  ...
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        392    6                                  C2            153 AVENUE B
# 3        402   21                                  C4     154 EAST 7TH STREET
# 4        404   55                                  C2  301 EAST 10TH   STREET
# 6        406   32                                  C4            210 AVENUE B
# 9        387  153                                  D9     629 EAST 5TH STREET
# ...      ...  ...       ...                       ...                     ...
# 84543   7349   34                                  B9           37 QUAIL LANE
# 84544   7349   78                                  B9        32 PHEASANT LANE
# 84545   7351   60                                  B2        49 PITNEY AVENUE
# 84546   7100   28                                  K6   2730 ARTHUR KILL ROAD
# 84547   7105  679                                  P9       155 CLAY PIT ROAD
#
#       APARTMENT NUMBER  ...  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                       ...            1633.0             6440.0        1900
# 3                       ...            2272.0             6794.0        1913
# 4                       ...            2369.0             4615.0        1900
# 6                       ...            1750.0             4226.0        1920
# 9                       ...            4489.0            18523.0        1920
# ...                ...  ...               ...                ...         ...
# 84543                   ...            2400.0             2575.0        1998
# 84544                   ...            2498.0             2377.0        1998
# 84545                   ...            4000.0             1496.0        1925
# 84546                   ...          208033.0            64117.0        2001
# 84547                   ...           10796.0             2400.0        2006
#
#        TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                              2                              C2   6625000.0
# 3                              2                              C4   3936272.0
# 4                              2                              C2   8000000.0
# 6                              2                              C4   3192840.0
# 9                              2                              D9  16232000.0
# ...                          ...                             ...         ...
# 84543                          1                              B9    450000.0
# 84544                          1                              B9    550000.0
# 84545                          1                              B2    460000.0
# 84546                          4                              K6  11693337.0
# 84547                          4                              P9     69300.0
#
#                  SALE DATE  AGE AGE STATS  SALE PRICE(000)
# 0      2017-07-19 00:00:00  123   PRE-WAR         6625.000
# 3      2016-09-23 00:00:00  110   PRE-WAR         3936.272
# 4      2016-11-17 00:00:00  123   PRE-WAR         8000.000
# 6      2016-09-23 00:00:00  103   PRE-WAR         3192.840
# 9      2016-11-07 00:00:00  103   PRE-WAR        16232.000
# ...                    ...  ...       ...              ...
# 84543  2016-11-28 00:00:00   25  POST-WAR          450.000
# 84544  2017-04-21 00:00:00   25  POST-WAR          550.000
# 84545  2017-07-05 00:00:00   98   PRE-WAR          460.000
# 84546  2016-12-21 00:00:00   22  POST-WAR        11693.337
# 84547  2016-10-27 00:00:00   17  POST-WAR           69.300
#
# [28439 rows x 24 columns]

# %%
sale_price = df['SALE PRICE(000)']

# %%
sale_price
# Out:
# 0         6625.000
# 3         3936.272
# 4         8000.000
# 6         3192.840
# 9        16232.000
#            ...
# 84543      450.000
# 84544      550.000
# 84545      460.000
# 84546    11693.337
# 84547       69.300
# Name: SALE PRICE(000), Length: 28439, dtype: float64

# %% [markdown]
# ### MEASURE OF CENTRAL TENDENCY

# %%
import math 
import statistics
import numpy as np
import scipy.stats 
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use(['Solarize_Light2'])

# %% [markdown]
# #### MEAN

# %%
# Nilai mean dari statistics
mean_stats = statistics.mean(sale_price)
mean_stats
# Out:
# 1511.1023442455783

# %%
# Nilai mean dari numpy
mean_np = np.mean(sale_price)
mean_np
# Out:
# 1511.1023442455744

# %%
# Nilai mean dari series
sale_price.mean()
# Out:
# 1511.1023442455744

# %%
mean_total_borough = df['SALE PRICE'].groupby(df['BOROUGH']).mean()

# %%
mean_total_borough.plot(kind='bar', figsize=(10,8), color='darkslateblue')
plt.title('Average Sale Price in NYC', y=1.02)
plt.xlabel('Borough', y=1.02, color='black', fontsize=14)
plt.ylabel('Average Sale Price', color='black', fontsize=14)
plt.show()

# %% [markdown]
# Dari hasil output rata-rata penjualan properti dari New York City didapat bahwa sebesar $ 1.511.102,35 dengan wilayah yang memiliki total rata-rata penjualan properti terbesar yaitu di wilayah Manhattan

# %% [markdown]
# #### MEDIAN

# %%
# Nilai median dari statistics
median_stat = statistics.median(sale_price)
median_stat
# Out:
# 635.0

# %%
# Nilai median dari numpy
median_np = np.median(sale_price)
median_np
# Out:
# 635.0

# %%
# Nilai median dari series
sale_price.median()
# Out:
# 635.0

# %% [markdown]
# Dari hasil output median dengan menggunakan packages statistics, numpy, dan function series diatas diperoleh median dari penjualan properti di New York sebesar $ 635.000

# %% [markdown]
# #### MODE/MODUS

# %%
# Nilai mode/modus dari statistics
mode_stat = statistics.mode(sale_price)
mode_stat
# Out:
# 700.0

# %%
# Nilai mode/modus dari scipy
mode_= scipy.stats.mode(sale_price)
print('Nilai Modusnya',mode_.mode)
print('Total Banyaknya Nilai Modus Muncul',mode_.count)
# Out:
# Nilai Modusnya [700.]
# Total Banyaknya Nilai Modus Muncul [290]

# %%
# Nilai mode/modus dari series
sale_price.mode()
# Out:
# 0    700.0
# Name: SALE PRICE(000), dtype: float64

# %% [markdown]
# Hasil dari nilai modus diatas menunjukkan bahwa penjualan properti yang paling sering terjadi di New York City selama 1 tahun periode yaitu sebesar $ 700.000 dengan penjualan dengan harga tersebut terjadi sebanyak 290 kali.

# %% [markdown]
# ### MEASURE OF SPREAD

# %% [markdown]
# #### RANGE (MAX-MIN)

# %%
# Nilai Range dengan menggunakan numpy 
np.ptp(sale_price)
# Out:
# 329994.3

# %%
# Nilai terbesar dari range dengan menggunakan numpy
np.amax(sale_price)
# Out:
# 330000.0

# %%
# Nilai terkecil dari range dengan menggunakan numpy
np.amin(sale_price)
# Out:
# 5.7

# %%
# Nilai range dari hasil pengurangan nilai terbesar dengan nilai terkecil
np.amax(sale_price)-np.amin(sale_price)
# Out:
# 329994.3

# %% [markdown]
# Hasil output diatas menjelaskan bahwa rentang nilai penjualan properti dari yang terkecil ke terbesar yaitu sebesar 329.994.300, dengan nilai terkecil yaitu $ 5700, dan nilai terbesarnya 330.000.000 (dalam satuan dollar).

# %% [markdown]
# #### VARIANCE

# %%
# Nilai Variance dengan menggunakan statistics
var_stat = statistics.variance(sale_price)
var_stat
# Out:
# 48899500.86331457

# %%
# Nilai variance dengan menggunakan numpy
var_np = np.var(sale_price, ddof=1)
var_np
# Out:
# 48899500.863314934

# %%
# Nilai variance dengan menggungakan series 
var_series = pd.Series(sale_price)
var_series.var()
# Out:
# 48899500.863314934

# %% [markdown]
# Dari hasil output dengan menggunakan packages statistics, numpy, dan series function didapat hasil varians yang sangat besar dari data penjualan properti tersebut yaitu sebesar 48.899.500.

# %% [markdown]
# #### STANDARD DEVIASI

# %%
# Nilai stdev dengan menggunakan statistics
std_stat = statistics.stdev(sale_price)
std_stat
# Out:
# 6992.817805671371

# %%
# Nilai stdev dengan menggunakan numpy
std_np = np.std(sale_price, ddof=1)
std_np
# Out:
# 6992.817805671397

# %%
# Nilai std dengan menggunakan series
std_series = pd.Series(sale_price)
std_series.std()
# Out:
# 6992.817805671397

# %% [markdown]
# Dari Hasil output dengan menggunakan statistics, numpy, dan series function didapat hasil dari standard deviasi data tersebut sebesar 6.992,818

# %% [markdown]
# ### PROBABILITY DISTRIBUTION

# %%
import seaborn as sns
sns.distplot(df['SALE PRICE'], color='darkslategrey')
plt.xlabel('Sale Price', fontsize=12, color='black')
plt.ylabel('Count',fontsize=12, color='black')
plt.title('Distribution of Sale Price in New York', y=1.04)
plt.show()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Terlihat dari distribusi plot dari data penjualan properti di New York diatas bahwa data sangat besar dan terlihat bahwa plot cendrung tidak normal dengan positive skewed, yang berarti nilai dari median>mean>modus nya.

# %%
# Distribution plot with log transformation
plt.figure(figsize=(10,6))
sns.distplot(np.log(df['SALE PRICE'].values), kde=True)
plt.xlabel('Sale Price', fontsize = 12, color='black')
plt.ylabel('Count', fontsize = 12, color='black')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Distribution of Sale Prince in New York After Log Transformation', y=1.02)
plt.show()
# Out:
# C:\Users\muham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Berikut merupakan hasil dari distribution plot dengan sebelumnya dilakukan transformasi dengan metode logaritmik (log transformation) untuk membuat meminimalisir outlier dan membuat data menjadi lebih normal terlihat bahwa data sudah cendrung normal.

# %% [markdown]
# ### CONFIDENCE INTERVAL

# %% [markdown]
# Selanjutnya akan dilakukan confidence interval pada kolom AGE untuk mengetahui interval data usia bangunan/properti pada data tersebut.

# %%
population_mean = df['AGE'].mean()
population_mean
# Out:
# 82.3009599493653

# %%
population_std = df['AGE'].std()
population_std
# Out:
# 30.516463699331442

# %% [markdown]
# **Pengambilan Sampel**

# %%
n = 50 
sample_means =[]
for sample in range(0,1000):
    sample_values = df['AGE'].sample(n)
    sample_mean = sample_values.mean()
    sample_means.append(sample_mean)

# %%
sns.displot(sample_means)
plt.title('Histogram of Sample Means AGE', y=1.02)
plt.xlabel('Age', fontsize=12, color='black')
plt.ylabel('Count', fontsize=12, color='black')
plt.show()

# %% [markdown]
# Terlihat dari grafik histogram diatas data sampel dari usia bangunan/properti data tersebut cenderung normal.

# %%
mean_of_sample_means = np.mean(sample_means)
median_of_sample_means = np.median(sample_means)
mean_of_sample_means, median_of_sample_means
# Out:
# (82.1795, 82.19)

# %%
standard_error = population_std/np.sqrt(n)
standard_error
# Out:
# 4.315679683926076

# %%
std_of_sample_means = np.std(sample_means)
std_of_sample_means
# Out:
# 4.329633258140925

# %% [markdown]
# Terlihat bahwa hasil dari standard error dengan standard eror sampel tidak jauh berbeda sehingga dapat dikatakan bahwa sampel memiliki karakteristik yang serupa dengan populasi.

# %%
z = 1.96

# %%
lower_bound = mean_of_sample_means - z * standard_error
lower_bound
# Out:
# 73.7207678195049

# %%
upper_bound = mean_of_sample_means + z * standard_error
upper_bound
# Out:
# 90.63823218049511

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace(np.min(sample_means),np.max(sample_means),100000)
plt.plot(pos,kde(pos))
shade = np.linspace(lower_bound,upper_bound,300)
plt.fill_between(shade,kde(shade), color='grey', alpha=0.5)
plt.xlabel('Sample Mass (Pounds)')
plt.ylabel('Frequency')
plt.axvline(x=mean_of_sample_means, color='red')
plt.title('Density Plot of Sample Means Age', y=1.02)
plt.xlabel('Age', fontsize=12, color='black')
plt.ylabel('Frequency', fontsize=12, color='black')
plt.text(x=80, y=0.02, s='Shaded Area are part of the Confidence Intervals')
plt.show()

# %%
print('Confidence Interval Age dengan tingkat kepercayaan sebesar 95% yaitu')
print('interval',lower_bound,'-', upper_bound)
# Out:
# Confidence Interval Age dengan tingkat kepercayaan sebesar 95% yaitu
# interval 73.7207678195049 - 90.63823218049511

# %% [markdown]
# Dari hasil confidence interval usia bangunan/properti dari data didapat interval usia dari bangunan/properti sebesar 74 tahun hingga 91 tahun.

# %% [markdown]
# ### HYPOTHESIS

# %% [markdown]
# **Dengan tingkat kepercayaan sebesar 95%**
#
# **Hipotesis**:
#
# **$H0$** : Rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) tidak lebih besar dari penjualan setelah masa perang (Post-War)
#
# **$H1$** : Rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) lebih besar dari penjualan setelah masa perang (Post-War)
#
# **$Alpha : 0.05$**

# %%
pre = df[df['AGE STATS']=='PRE-WAR']
post = df[df['AGE STATS']=='POST-WAR']

# %%
# Jumlah data, mean, dan standard deviasi
n_pre = len(pre)
mean_pre = pre['SALE PRICE(000)'].mean()
std_pre = pre['SALE PRICE(000)'].std()
print(n_pre,mean_pre,std_pre)
# Out:
# 18635 1613.2205960826402 6836.1127421139945

# %%
# Jumlah data, mean, dan standard deviasi
n_post = len(post)
mean_post = post['SALE PRICE(000)'].mean()
std_post = post['SALE PRICE(000)'].std()
print(n_post,mean_post,std_post)
# Out:
# 9804 1317.000587515301 7277.79099295987

# %%
post
# Out:
#              BOROUGH   NEIGHBORHOOD  \
# 11         Manhattan  ALPHABET CITY
# 234        Manhattan        CHELSEA
# 239        Manhattan        CHELSEA
# 929        Manhattan        CHELSEA
# 937        Manhattan        CHELSEA
# ...              ...            ...
# 84541  Staten Island        WOODROW
# 84543  Staten Island        WOODROW
# 84544  Staten Island        WOODROW
# 84546  Staten Island        WOODROW
# 84547  Staten Island        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 11     08 RENTALS - ELEVATOR APARTMENTS                              2B
# 234    08 RENTALS - ELEVATOR APARTMENTS                              2B
# 239    08 RENTALS - ELEVATOR APARTMENTS                               2
# 929    21 OFFICE BUILDINGS                                            4
# 937    22 STORE BUILDINGS                                             4
# ...                                            ...                  ...
# 84541  02 TWO FAMILY DWELLINGS                                        1
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 11       400   21                                  D1
# 234      695    6                                  D6
# 239      794   11                                  D7
# 929      790   32                                  O1
# 937      696   28                                  K1
# ...      ...  ...       ...                       ...
# 84541   7317  126                                  B2
# 84543   7349   34                                  B9
# 84544   7349   78                                  B9
# 84546   7100   28                                  K6
# 84547   7105  679                                  P9
#
#                           ADDRESS APARTMENT NUMBER  ...  LAND SQUARE FEET  \
# 11        530-532 EAST 5TH STREET                   ...            3717.0
# 234        559 WEST 23RD   STREET                   ...            2469.0
# 239                 155 WEST 18TH                   ...           10053.0
# 929    531-537 AVENUE OF THE AMER                   ...            6468.0
# 937                 507 WEST 24TH                   ...            3950.0
# ...                           ...              ...  ...               ...
# 84541             112 ROBIN COURT                   ...           11088.0
# 84543               37 QUAIL LANE                   ...            2400.0
# 84544            32 PHEASANT LANE                   ...            2498.0
# 84546       2730 ARTHUR KILL ROAD                   ...          208033.0
# 84547           155 CLAY PIT ROAD                   ...           10796.0
#
#        GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 11               12350.0        2009                          2
# 234              19892.0        2014                          2
# 239              78882.0        2014                          2
# 929              14056.0        1953                          4
# 937               7900.0        2013                          4
# ...                  ...         ...                        ...
# 84541             2160.0        1994                          1
# 84543             2575.0        1998                          1
# 84544             2377.0        1998                          1
# 84546            64117.0        2001                          4
# 84547             2400.0        2006                          4
#
#        BUILDING CLASS AT TIME OF SALE  SALE PRICE            SALE DATE  AGE  \
# 11                                 D1  10350000.0  2016-10-17 00:00:00   14
# 234                                D6   4600000.0  2016-11-29 00:00:00    9
# 239                                D7   2341975.0  2016-10-28 00:00:00    9
# 929                                O1  42400000.0  2017-04-18 00:00:00   70
# 937                                K1  10750000.0  2016-12-28 00:00:00   10
# ...                               ...         ...                  ...  ...
# 84541                              B2    648000.0  2016-12-07 00:00:00   29
# 84543                              B9    450000.0  2016-11-28 00:00:00   25
# 84544                              B9    550000.0  2017-04-21 00:00:00   25
# 84546                              K6  11693337.0  2016-12-21 00:00:00   22
# 84547                              P9     69300.0  2016-10-27 00:00:00   17
#
#       AGE STATS  SALE PRICE(000)
# 11     POST-WAR        10350.000
# 234    POST-WAR         4600.000
# 239    POST-WAR         2341.975
# 929    POST-WAR        42400.000
# 937    POST-WAR        10750.000
# ...         ...              ...
# 84541  POST-WAR          648.000
# 84543  POST-WAR          450.000
# 84544  POST-WAR          550.000
# 84546  POST-WAR        11693.337
# 84547  POST-WAR           69.300
#
# [9804 rows x 24 columns]

# %%
import statsmodels.api as sm

# %%
# Dengan tingkat kepercayaan sebesar 95% maka alpha = 0.05
alpha = 0.05

# %%
price_hypo = sm.stats.ztest(pre['SALE PRICE(000)'].dropna(),
                            post['SALE PRICE(000)'].dropna(), alternative='two-sided')

# %%
price_hypo
# Out:
# (3.3958755928809983, 0.0006840944507895855)

# %%
if price_hypo[1]>alpha:
    print('Terima Hipotesis nol(H0) Rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) tidak lebih besar dari penjualan setelah masa perang (Post-War)')
else:
    print('Reject Hipotesis nol(H0) Rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) lebih besar dari penjualan setelah masa perang (Post-War)')
# Out:
# Reject Hipotesis nol(H0) Rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) lebih besar dari penjualan setelah masa perang (Post-War)

# %% [markdown]
# Dari hasil uji hipotesis diatas didapat bahwa tolak H0 yang mana artinya terima hipotesis alternatif (H1) yaitu rata-rata penjualan bangunan/properti sebelum masa perang (Pre-War) lebih besar dari penjualan setelah masa perang (Post-War).

# %% [markdown]
# ## 6. Kesimpulan
#
# > Dari hasil analisis data penjualan properti/bangunan di New York selama 1 tahun periode, dapat diambil kesimpulan bahwa total rata-rata penjualan bangunan terbesar terjadi di wilayah Manhattan dengan total rata-rata penjualan properti sebesar $ 1.511.102,35. Didapat juga bahwa bangunan yang telah berdiri sebelum jaman perang (Pre-War) memiliki rata-rata penjualan yang lebih besar dibanding dengan bangunan/properti yang baru dibangun atau dibangun setelah masa peperangan usai (Post-War).
